# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread("./images/input.jpg")

alpha = float(input("Enter the alpha value [0.1-3.0]: "))
beta = int(input("Enter the beta value [0-100]: "))

new_image = cv.convertScaleAbs(image, alpha=alpha, beta=beta)

plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.imshow(image[..., ::-1])
plt.title("Original")
plt.subplot(122)
plt.imshow(new_image[..., ::-1])
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %%
image = cv.imread("./images/input.jpg")

new_image2 = np.zeros(image.shape, image.dtype)

alpha = float(input("Enter the alpha value [0.1-3.0]: "))
beta = int(input("Enter the beta value [0-100]: "))

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image2[y][x][c] = np.clip(alpha * image[y, x, c] + beta, 0, 255)

plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.imshow(image[..., ::-1])
plt.title("Original")
plt.subplot(122)
plt.imshow(new_image2[..., ::-1])
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %% [markdown]
# ## Histogram analysis

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
gray_new_image = cv.cvtColor(new_image, cv.COLOR_BGR2GRAY)
gray_new_image2 = cv.cvtColor(new_image2, cv.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.hist(gray_image.ravel(), 256, (0, 256))
plt.title("Original")
plt.subplot(132)
plt.hist(gray_new_image.ravel(), 256, (0, 256))
plt.title("new_image")
plt.subplot(133)
plt.hist(gray_new_image2.ravel(), 256, (0, 256))
plt.title("new_image2")
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_10224\1426224168.py:3: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gray_image.ravel(), 256, (0, 256))
# C:\Users\Amir\AppData\Local\Temp\ipykernel_10224\1426224168.py:6: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gray_new_image.ravel(), 256, (0, 256))
# C:\Users\Amir\AppData\Local\Temp\ipykernel_10224\1426224168.py:9: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gray_new_image2.ravel(), 256, (0, 256))
# Text(0.5, 1.0, 'new_image2')
