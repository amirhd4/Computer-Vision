# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="./datasets/plate_persian/data.yaml",  # path to dataset YAML
    epochs=45,  # number of training epochs
    imgsz=224,  # training image size
    device="cpu",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)

# Evaluate model performance on the validation set
metrics = model.val()

# # Perform object detection on an image
# results = model("path/to/image.jpg")
# results[0].show()

# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model
# Out:
# New https://pypi.org/project/ultralytics/8.3.88 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.86  Python-3.12.9 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-12400)
# ...

# %%
# Perform object detection on an image
results = model("./images/car_plate1.jpg")
results[0].show()
# Out:
# image 1/1 C:\Users\Amir\Desktop\test\Computer-Vision\deep-learning\images\car_plate1.jpg: 128x224 3 plates, 16.8ms
# Speed: 0.6ms preprocess, 16.8ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 224)

# %%
from IPython.display import Image
import cv2 as cv

fig = plt.figure(figsize=(20, 15))
plt.subplot(221)
plt.axis("off")
plt.imshow(cv.imread("./models/persian_plate/F1_curve.png")[...,::-1])
plt.subplot(222)
plt.axis("off")
plt.imshow(cv.imread("./models/persian_plate/PR_curve.png")[...,::-1])
plt.subplot(223)
plt.axis("off")
plt.imshow(cv.imread("./models/persian_plate/confusion_matrix.png")[...,::-1])

plt.show()

# %% [markdown]
# ## Load and use pre-trained model

# %%
model = YOLO("./models/persian_plate/weights/best.pt")

# %%
import os

test_images = os.listdir('./datasets/plate_persian/test/images/')
test_dir = "./datasets/plate_persian/test/images/"

# results = model([test_dir + i for i in test_images])
results = model(test_dir)

# results[0].show()
# Out:
# image 1/37 C:\Users\Amir\Desktop\test\Computer-Vision\deep-learning\datasets\plate_persian\test\images\104_jpg.rf.3a6d71a6285975b89e3064079fddf2f8.jpg: 224x224 1 plate, 15.5ms
# image 2/37 C:\Users\Amir\Desktop\test\Computer-Vision\deep-learning\datasets\plate_persian\test\images\120_jpg.rf.fce7ad8eea4730ab95b550bcc68d6880.jpg: 224x224 1 plate, 13.8ms
# image 3/37 C:\Users\Amir\Desktop\test\Computer-Vision\deep-learning\datasets\plate_persian\test\images\125_jpg.rf.fc1a072467efb653f5b439037a8a7535.jpg: 224x224 1 plate, 14.0ms
# image 4/37 C:\Users\Amir\Desktop\test\Computer-Vision\deep-learning\datasets\plate_persian\test\images\167_jpg.rf.d79d0bdf728c09fc19a9e78752a5d97f.jpg: 224x224 1 plate, 14.1ms
# image 5/37 C:\Users\Amir\Desktop\test\Computer-Vision\deep-learning\datasets\plate_persian\test\images\177_jpg.rf.575a0e5f7564551ae6bf42d59249a2b4.jpg: 224x224 1 plate, 14.1ms
# ...

# %%
for predicted in results:
    predicted.show()
