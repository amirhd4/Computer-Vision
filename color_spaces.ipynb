# %% [markdown]
# ## More about RGB(or BGR) images

# %%
import cv2
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread("./images/color.png")
b,g,r = cv.split(img)

plt.figure(figsize=(20,5))
plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

plt.subplot(144);plt.imshow(img[:,:,::-1]);plt.title("All Channels")
# Out:
# Text(0.5, 1.0, 'All Channels')

# %%
img = cv.imread("./images/input.jpg")
b,g,r = cv.split(img)

plt.figure(figsize=(20,5))
plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

plt.subplot(144);plt.imshow(img[:,:,::-1]);plt.title("All Channels")
# Out:
# Text(0.5, 1.0, 'All Channels')

# %% [markdown]
# ## How to merge channels to form an image

# %%
merged = cv.merge([b,g,r])

plt.figure(figsize=(20,5))
plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

plt.subplot(144);plt.imshow(merged[:,:,::-1]);plt.title("All Channels")
# Out:
# Text(0.5, 1.0, 'All Channels')

# %%
np.zeros_like([[2,5,6], [4, 6, 6]])
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
zeros = np.zeros_like(r, "uint8")


red = cv.merge([zeros, zeros, r])
green = cv.merge([zeros, g, zeros])
blue = cv.merge([b, zeros, zeros])

plt.figure(figsize=(20,5))
plt.subplot(141);plt.imshow(red[...,::-1], cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(green[...,::-1], cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(blue[...,::-1], cmap="gray");plt.title("Blue Channel")
# Out:
# Text(0.5, 1.0, 'Blue Channel')
